# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/rasheed-hammad/machine-learning-starter/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
# My Lane will be Refresh/Content Opportuinity Scoring
"""
I chose the Refresh / Content Opportunity Scoring lane because the starter dataset contains multiple observable signals
about content performance,including impressions, CTR, average position, content age, freshness, and engagement.
My goal is to investigate whether these signals can help prioritize pages for human review rather than treating every page equally.
"""

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
# Decision: Which pages should be reviewed first for potential content improvement?

# Who acts: An SEO or content editor/team.

# Action: The team reviews the highest-priority pages and decides whether they should be refreshed, expanded, improved, monitored, or handled in another appropriate way.

# Cost of a wrong call: If a page is incorrectly prioritized, an editor may waste limited time reviewing or updating a page that does not need attention.
#     If an important page is missed, the team may fail to investigate a potentially valuable content opportunity.

# Why data/ML can help: The dataset contains multiple observable signals, such as impressions, CTR, average position, content age, freshness, and engagement.
#   These signals may interact with each other, making it difficult to combine them effectively using a simple hand-written rule. Data analysis and ML may help identify useful patterns and prioritize pages more effectively.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import os
import sys
import subprocess
import pandas as pd

# loading github repo
REPO_URL = "https://github.com/rasheed-hammad/machine-learning-starter.git"
REPO_DIR = "machine-learning-starter"

if "google.colab" in sys.modules:
    if not os.path.isdir(REPO_DIR):
        subprocess.run(
            ["git", "clone", "--depth", "1", REPO_URL, REPO_DIR],
            check=True
        )
    os.chdir(REPO_DIR)

    subprocess.run(
        [sys.executable, "-m", "pip", "install", "-q", "-r", "requirements.txt"],
        check=True
    )

# loading the starter CSV
csv_path = "data/raw/content_refresh_anonymized.csv"

assert os.path.exists(csv_path), "CSV file not found!"

df = pd.read_csv(csv_path)

print("Repository opened successfully.")
print("Working directory:", os.getcwd())
print("CSV loaded successfully.")
print("Dataset shape:", df.shape)
# display first 5 rows
df.head()
# Out:
# Repository opened successfully.
# Working directory: /content/machine-learning-starter
# CSV loaded successfully.
# Dataset shape: (30000, 44)
#              content_id          client_id  search_volume  competition  \
# 0  content_304f48230142  client_f369cb89fc           10.0         0.67
# 1  content_a1fb4e703a9e  client_4e07408562           90.0         0.01
# 2  content_9aa793d4d895  client_7f2253d7e2            0.0         0.00
# 3  content_331d6c4de07b  client_19581e27de           10.0         0.00
# 4  content_d99b7a2d90ca  client_3fdba35f04            0.0         0.00
#
#   competition_level   cpc     content_type    main_intent  word_count  \
# 0              HIGH  2.05  keyword article  transactional      3221.0
# 1               LOW  0.05  keyword article  informational      2481.0
# 2               LOW  0.00  keyword article  informational      3515.0
# 3               LOW  0.00  keyword article     commercial         NaN
# ...

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
# I can investigate whether observable signals are associated with content performance and whether they can help prioritize pages for review.
# I cannot prove that a particular factor causes Google rankings to change.
# Also I cannot guarantee that refreshing a page will increase traffic.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
